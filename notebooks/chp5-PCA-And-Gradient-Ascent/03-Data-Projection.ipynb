# %% [markdown]
# # 从高维数据向低维数据的映射

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.empty((100, 2))
X[:,0] = np.random.uniform(0., 100., size=100)
X[:,1] = 0.75 * X[:,0] + 3. + np.random.normal(0, 10., size=100)

# %%
from playML.PCA import PCA

pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
pca.components_
# Out:
# array([[ 0.74802244,  0.66367344],
#        [-0.66367095,  0.74802464]])

# %%
pca = PCA(n_components=1)
pca.fit(X)
# Out:
# PCA(n_components=1)

# %%
X_reduction = pca.transform(X)

# %%
X_reduction.shape
# Out:
# (100, 1)

# %%
X_restore = pca.inverse_transform(X_reduction)

# %%
X_restore.shape
# Out:
# (100, 2)

# %%
plt.scatter(X[:,0], X[:,1], color='b', alpha=0.5, label="X")
plt.scatter(X_restore[:,0], X_restore[:,1], color='r', alpha=0.5, label="X_m")
plt.legend()
plt.show()
# plt.savefig("PCAAndGradientAscent_10.png", dpi=300)

# %% [markdown]
# ### scikit-learn中的PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1)
pca.fit(X)
# Out:
# PCA(n_components=1)

# %%
pca.components_
# Out:
# array([[0.74802229, 0.6636736 ]])

# %%
X_reduction = pca.transform(X)
X_restore = pca.inverse_transform(X_reduction)

# %%
plt.scatter(X[:,0], X[:,1], color='b', alpha=0.5)
plt.scatter(X_restore[:,0], X_restore[:,1], color='r', alpha=0.5)
plt.show()
